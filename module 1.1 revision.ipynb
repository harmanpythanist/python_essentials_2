# %%
import math

print(math.pi)
print(math.sin(20))
print(math.cos(40))
# Out:
# 3.141592653589793
# 0.9129452507276277
# -0.6669380616522619

# %%
import math as m

print(m.pi, m.sin(20), m.cos(40))
# Out:
# 3.141592653589793 0.9129452507276277 -0.6669380616522619

# %%
from math import pi

#math.pi # not work
print(pi)  # will work
# Out:
# 3.141592653589793

# %%
from math import pi as value_of_pi_variable
#math, pi are not defined

print(value_of_pi_variable)
# Out:
# 3.141592653589793

# %%
from math import sin as s, pi as p, cos as c

print(s(p))
print(c(p))
#sin(3.1423243)
# Out:
# 1.2246467991473532e-16
# -1.0

# %%
from math import *
# math not defined
# everything in math is defined: pi, cos, sin, tan... all

# %%
import math

def sin(x):
    print("This is user function")
    # no return: None
pi = 40

print(sin(pi)) # NONE

print(math.sin(math.pi))
# Out:
# This is user function
# None
# 1.2246467991473532e-16

# %%
dir(math) # member functions, member variables = entity
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
len(dir(math))
# Out:
# 66
