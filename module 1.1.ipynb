# %%
import math

print(math.pi)
print(math.cos(10))
print(math.sin(20))
# Out:
# 3.141592653589793
# -0.8390715290764524
# 0.9129452507276277

# %%
import math as m

print(m.pi)
print(m.cos(10))
print(m.sin(20))
# Out:
# 3.141592653589793
# -0.8390715290764524
# 0.9129452507276277

# %%
from math import pi as value_of_pi

print(value_of_pi)
print(round(value_of_pi, 2))

value_of_pi = 5
print(value_of_pi)
# Out:
# 3.141592653589793
# 3.14
# 5

# %%
from math import *
# from math import pi, cos, sin, tan, e, exp, .......,

# %%
from numpy import array as ar, arange as an

# %%
import numpy as np
len(dir(math))
# Out:
# 67

# %%
import math

def sin(x):
    if 2*x == pi:
        return 0.99
    else:
        return None

pi = 3.14
print(sin(pi/2))  # sin(1.57)   -> 0.99
print(math.sin(math.pi/2))   #    -> 1
# Out:
# 0.99
# 1.0
